# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/drive/MyDrive/data/combined_data.csv')

# %%
df.head()
# Out:
#       T    TM   Tm     SLP     H   VV    V    VM      PM 2.5
# 0   7.4   9.8  4.8  1017.6  93.0  0.5  4.3   9.4  219.720833
# 1   7.8  12.7  4.4  1018.5  87.0  0.6  4.4  11.1  182.187500
# 2   6.7  13.4  2.4  1019.4  82.0  0.6  4.8  11.1  154.037500
# 3   8.6  15.5  3.3  1018.7  72.0  0.8  8.1  20.6  223.208333
# 4  12.4  20.9  4.4  1017.3  61.0  1.3  8.7  22.2  200.645833

# %%
df=df.dropna() # since only null value is there. we are droping it..if it has more then we would be replaced it with mean,median,mode

# %%
x = df.iloc[:,:-1] ## independent features
y = df.iloc[:,-1] ## dependent features

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=0)

# %%
import xgboost as xgb

# %%
regressor=xgb.XGBRegressor()
regressor.fit(X_train,y_train)
# Out:
# [12:17:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor()

# %%
print("Coefficient of determination R^2 <-- on train set: {}".format(regressor.score(X_train, y_train)))
print("Coefficient of determination R^2 <-- on train set: {}".format(regressor.score(X_test, y_test)))
# Out:
# Coefficient of determination R^2 <-- on train set: 0.8606305938167513
# Coefficient of determination R^2 <-- on train set: 0.7210652962292528

# %%
from sklearn.model_selection import cross_val_score
score=cross_val_score(regressor,x,y,cv=5)
# Out:
# [12:18:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:18:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:18:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:18:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:18:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.

# %%
score.mean()
# Out:
# 0.6582827367763413

# %%
prediction=regressor.predict(X_test)

# %%
sns.distplot(y_test-prediction)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.scatter(y_test,prediction)

# %% [markdown]
# hyperparameter tuning

# %%
xgb.XGBRegressor()
# Out:
# XGBRegressor()

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1200, num = 12)]
print(n_estimators)
# Out:
# [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200]

# %%
#Randomized Search CV

# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1200, num = 12)]
# Various learning rate parameters
learning_rate = ['0.05','0.1', '0.2','0.3','0.5','0.6']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(5, 30, num = 6)]
# max_depth.append(None)
#Subssample parameter values
subsample=[0.7,0.6,0.8]
# Minimum child weight parameters
min_child_weight=[3,4,5,6,7]

# %%
random_grid = {'n_estimators': n_estimators,
               'learning_rate': learning_rate,
               'max_depth': max_depth,
               'subsample': subsample,
               'min_child_weight': min_child_weight}

print(random_grid)
# Out:
# {'n_estimators': [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200], 'learning_rate': ['0.05', '0.1', '0.2', '0.3', '0.5', '0.6'], 'max_depth': [5, 10, 15, 20, 25, 30], 'subsample': [0.7, 0.6, 0.8], 'min_child_weight': [3, 4, 5, 6, 7]}

# %%
# Use the random grid to search for best hyperparameters
# First create the base model to tune
regressor=xgb.XGBRegressor()

# %%
xg_random = RandomizedSearchCV(estimator = regressor, param_distributions = random_grid,scoring='neg_mean_squared_error', n_iter = 100, cv = 5, verbose=2)

# %%
xg_random.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [12:21:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.5, max_depth=15, min_child_weight=4, n_estimators=1000, subsample=0.7; total time=   0.6s
# [12:21:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.5, max_depth=15, min_child_weight=4, n_estimators=1000, subsample=0.7; total time=   0.6s
# [12:21:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.5, max_depth=15, min_child_weight=4, n_estimators=1000, subsample=0.7; total time=   0.6s
# [12:21:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.5, max_depth=15, min_child_weight=4, n_estimators=1000, subsample=0.7; total time=   0.5s
# [12:21:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.5, max_depth=15, min_child_weight=4, n_estimators=1000, subsample=0.7; total time=   0.5s
# [12:21:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.5, max_depth=25, min_child_weight=7, n_estimators=700, subsample=0.8; total time=   0.7s
# [12:21:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.5, max_depth=25, min_child_weight=7, n_estimators=700, subsample=0.8; total time=   1.0s
# [12:21:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.5, max_depth=25, min_child_weight=7, n_estimators=700, subsample=0.8; total time=   1.1s
# [12:21:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.5, max_depth=25, min_child_weight=7, n_estimators=700, subsample=0.8; total time=   0.6s
# [12:21:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.5, max_depth=25, min_child_weight=7, n_estimators=700, subsample=0.8; total time=   0.9s
# [12:21:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.2, max_depth=15, min_child_weight=3, n_estimators=800, subsample=0.8; total time=   0.7s
# [12:21:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.2, max_depth=15, min_child_weight=3, n_estimators=800, subsample=0.8; total time=   0.7s
# [12:21:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.2, max_depth=15, min_child_weight=3, n_estimators=800, subsample=0.8; total time=   0.9s
# [12:21:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.2, max_depth=15, min_child_weight=3, n_estimators=800, subsample=0.8; total time=   0.9s
# [12:21:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.2, max_depth=15, min_child_weight=3, n_estimators=800, subsample=0.8; total time=   0.8s
# [12:21:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=3, n_estimators=1000, subsample=0.7; total time=   1.9s
# [12:21:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=3, n_estimators=1000, subsample=0.7; total time=   1.6s
# [12:21:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=3, n_estimators=1000, subsample=0.7; total time=   1.7s
# [12:21:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=3, n_estimators=1000, subsample=0.7; total time=   1.5s
# [12:21:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=3, n_estimators=1000, subsample=0.7; total time=   1.7s
# [12:21:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=6, n_estimators=900, subsample=0.8; total time=   1.8s
# [12:21:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=6, n_estimators=900, subsample=0.8; total time=   1.8s
# [12:21:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=6, n_estimators=900, subsample=0.8; total time=   1.9s
# [12:21:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=6, n_estimators=900, subsample=0.8; total time=   1.8s
# [12:22:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.1, max_depth=20, min_child_weight=6, n_estimators=900, subsample=0.8; total time=   1.8s
# [12:22:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.6, max_depth=10, min_child_weight=6, n_estimators=1100, subsample=0.8; total time=   0.5s
# [12:22:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.6, max_depth=10, min_child_weight=6, n_estimators=1100, subsample=0.8; total time=   0.7s
# [12:22:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.6, max_depth=10, min_child_weight=6, n_estimators=1100, subsample=0.8; total time=   0.4s
# [12:22:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.6, max_depth=10, min_child_weight=6, n_estimators=1100, subsample=0.8; total time=   1.0s
# [12:22:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.6, max_depth=10, min_child_weight=6, n_estimators=1100, subsample=0.8; total time=   0.4s
# [12:22:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.05, max_depth=5, min_child_weight=7, n_estimators=200, subsample=0.7; total time=   0.1s
# [12:22:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.05, max_depth=5, min_child_weight=7, n_estimators=200, subsample=0.7; total time=   0.1s
# [12:22:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.05, max_depth=5, min_child_weight=7, n_estimators=200, subsample=0.7; total time=   0.1s
# [12:22:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.05, max_depth=5, min_child_weight=7, n_estimators=200, subsample=0.7; total time=   0.2s
# [12:22:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.05, max_depth=5, min_child_weight=7, n_estimators=200, subsample=0.7; total time=   0.1s
# [12:22:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=5, n_estimators=600, subsample=0.6; total time=   0.7s
# [12:22:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=5, n_estimators=600, subsample=0.6; total time=   0.6s
# [12:22:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=5, n_estimators=600, subsample=0.6; total time=   0.9s
# [12:22:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=5, n_estimators=600, subsample=0.6; total time=   0.7s
# [12:22:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.5, max_depth=30, min_child_weight=5, n_estimators=600, subsample=0.6; total time=   0.8s
# [12:22:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=5, n_estimators=200, subsample=0.7; total time=   0.3s
# [12:22:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=5, n_estimators=200, subsample=0.7; total time=   0.3s
# [12:22:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=5, n_estimators=200, subsample=0.7; total time=   0.3s
# [12:22:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=5, n_estimators=200, subsample=0.7; total time=   0.3s
# [12:22:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=5, n_estimators=200, subsample=0.7; total time=   0.3s
# [12:22:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=3, n_estimators=800, subsample=0.7; total time=   0.5s
# [12:22:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=3, n_estimators=800, subsample=0.7; total time=   0.5s
# [12:22:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=3, n_estimators=800, subsample=0.7; total time=   0.5s
# [12:22:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=3, n_estimators=800, subsample=0.7; total time=   0.8s
# [12:22:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=3, n_estimators=800, subsample=0.7; total time=   0.5s
# [12:22:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.6, max_depth=20, min_child_weight=6, n_estimators=500, subsample=0.6; total time=   0.9s
# [12:22:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.6, max_depth=20, min_child_weight=6, n_estimators=500, subsample=0.6; total time=   0.8s
# [12:22:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.6, max_depth=20, min_child_weight=6, n_estimators=500, subsample=0.6; total time=   0.7s
# [12:22:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.6, max_depth=20, min_child_weight=6, n_estimators=500, subsample=0.6; total time=   0.7s
# [12:22:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.6, max_depth=20, min_child_weight=6, n_estimators=500, subsample=0.6; total time=   0.9s
# [12:22:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.6, max_depth=25, min_child_weight=7, n_estimators=1000, subsample=0.8; total time=   0.7s
# [12:22:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.6, max_depth=25, min_child_weight=7, n_estimators=1000, subsample=0.8; total time=   1.1s
# [12:22:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.6, max_depth=25, min_child_weight=7, n_estimators=1000, subsample=0.8; total time=   0.6s
# [12:22:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.6, max_depth=25, min_child_weight=7, n_estimators=1000, subsample=0.8; total time=   0.6s
# [12:22:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.6, max_depth=25, min_child_weight=7, n_estimators=1000, subsample=0.8; total time=   0.8s
# [12:22:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.3, max_depth=15, min_child_weight=6, n_estimators=1200, subsample=0.7; total time=   1.2s
# [12:22:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.3, max_depth=15, min_child_weight=6, n_estimators=1200, subsample=0.7; total time=   1.5s
# [12:22:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.3, max_depth=15, min_child_weight=6, n_estimators=1200, subsample=0.7; total time=   1.7s
# [12:22:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.3, max_depth=15, min_child_weight=6, n_estimators=1200, subsample=0.7; total time=   2.0s
# [12:22:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.3, max_depth=15, min_child_weight=6, n_estimators=1200, subsample=0.7; total time=   1.3s
# [12:22:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=7, n_estimators=300, subsample=0.7; total time=   0.6s
# [12:22:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=7, n_estimators=300, subsample=0.7; total time=   0.6s
# [12:22:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=7, n_estimators=300, subsample=0.7; total time=   0.6s
# [12:22:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=7, n_estimators=300, subsample=0.7; total time=   0.6s
# [12:22:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=7, n_estimators=300, subsample=0.7; total time=   0.6s
# [12:22:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.5, max_depth=5, min_child_weight=3, n_estimators=1200, subsample=0.7; total time=   0.4s
# [12:22:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.5, max_depth=5, min_child_weight=3, n_estimators=1200, subsample=0.7; total time=   0.5s
# [12:22:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.5, max_depth=5, min_child_weight=3, n_estimators=1200, subsample=0.7; total time=   0.4s
# [12:22:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.5, max_depth=5, min_child_weight=3, n_estimators=1200, subsample=0.7; total time=   0.5s
# [12:22:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.5, max_depth=5, min_child_weight=3, n_estimators=1200, subsample=0.7; total time=   0.5s
# [12:22:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.05, max_depth=25, min_child_weight=6, n_estimators=1100, subsample=0.8; total time=   2.3s
# [12:22:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.05, max_depth=25, min_child_weight=6, n_estimators=1100, subsample=0.8; total time=   2.2s
# [12:22:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.05, max_depth=25, min_child_weight=6, n_estimators=1100, subsample=0.8; total time=   2.3s
# [12:22:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.05, max_depth=25, min_child_weight=6, n_estimators=1100, subsample=0.8; total time=   2.2s
# [12:22:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.05, max_depth=25, min_child_weight=6, n_estimators=1100, subsample=0.8; total time=   2.2s
# [12:22:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=6, n_estimators=400, subsample=0.7; total time=   0.8s
# [12:22:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=6, n_estimators=400, subsample=0.7; total time=   0.8s
# [12:22:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=6, n_estimators=400, subsample=0.7; total time=   0.8s
# [12:22:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=6, n_estimators=400, subsample=0.7; total time=   0.8s
# [12:22:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=6, n_estimators=400, subsample=0.7; total time=   0.8s
# [12:22:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.6, max_depth=25, min_child_weight=5, n_estimators=1200, subsample=0.7; total time=   0.8s
# [12:22:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.6, max_depth=25, min_child_weight=5, n_estimators=1200, subsample=0.7; total time=   0.9s
# [12:22:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.6, max_depth=25, min_child_weight=5, n_estimators=1200, subsample=0.7; total time=   0.6s
# [12:22:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.6, max_depth=25, min_child_weight=5, n_estimators=1200, subsample=0.7; total time=   1.2s
# [12:22:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.6, max_depth=25, min_child_weight=5, n_estimators=1200, subsample=0.7; total time=   1.0s
# [12:22:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=7, n_estimators=900, subsample=0.7; total time=   1.1s
# [12:22:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=7, n_estimators=900, subsample=0.7; total time=   1.3s
# [12:22:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=7, n_estimators=900, subsample=0.7; total time=   1.2s
# [12:22:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=7, n_estimators=900, subsample=0.7; total time=   1.7s
# [12:22:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=7, n_estimators=900, subsample=0.7; total time=   1.2s
# [12:23:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=5, n_estimators=900, subsample=0.8; total time=   1.1s
# [12:23:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=5, n_estimators=900, subsample=0.8; total time=   1.2s
# [12:23:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=5, n_estimators=900, subsample=0.8; total time=   1.2s
# [12:23:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=5, n_estimators=900, subsample=0.8; total time=   1.8s
# [12:23:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=5, n_estimators=900, subsample=0.8; total time=   0.8s
# [12:23:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=5, n_estimators=1200, subsample=0.6; total time=   1.1s
# [12:23:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=5, n_estimators=1200, subsample=0.6; total time=   0.7s
# [12:23:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=5, n_estimators=1200, subsample=0.6; total time=   1.0s
# [12:23:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=5, n_estimators=1200, subsample=0.6; total time=   0.6s
# [12:23:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=5, n_estimators=1200, subsample=0.6; total time=   0.8s
# [12:23:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.5, max_depth=25, min_child_weight=7, n_estimators=900, subsample=0.6; total time=   1.4s
# [12:23:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.5, max_depth=25, min_child_weight=7, n_estimators=900, subsample=0.6; total time=   1.3s
# [12:23:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.5, max_depth=25, min_child_weight=7, n_estimators=900, subsample=0.6; total time=   1.3s
# [12:23:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.5, max_depth=25, min_child_weight=7, n_estimators=900, subsample=0.6; total time=   1.1s
# [12:23:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.5, max_depth=25, min_child_weight=7, n_estimators=900, subsample=0.6; total time=   1.2s
# [12:23:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.2, max_depth=10, min_child_weight=3, n_estimators=700, subsample=0.7; total time=   0.8s
# [12:23:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.2, max_depth=10, min_child_weight=3, n_estimators=700, subsample=0.7; total time=   0.6s
# [12:23:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.2, max_depth=10, min_child_weight=3, n_estimators=700, subsample=0.7; total time=   0.6s
# [12:23:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.2, max_depth=10, min_child_weight=3, n_estimators=700, subsample=0.7; total time=   0.8s
# [12:23:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.2, max_depth=10, min_child_weight=3, n_estimators=700, subsample=0.7; total time=   0.6s
# [12:23:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.2, max_depth=5, min_child_weight=6, n_estimators=900, subsample=0.7; total time=   0.6s
# [12:23:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.2, max_depth=5, min_child_weight=6, n_estimators=900, subsample=0.7; total time=   0.6s
# [12:23:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.2, max_depth=5, min_child_weight=6, n_estimators=900, subsample=0.7; total time=   0.6s
# [12:23:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.2, max_depth=5, min_child_weight=6, n_estimators=900, subsample=0.7; total time=   0.7s
# [12:23:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.2, max_depth=5, min_child_weight=6, n_estimators=900, subsample=0.7; total time=   0.7s
# [12:23:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=3, n_estimators=200, subsample=0.6; total time=   0.3s
# [12:23:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=3, n_estimators=200, subsample=0.6; total time=   0.3s
# [12:23:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=3, n_estimators=200, subsample=0.6; total time=   0.3s
# [12:23:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=3, n_estimators=200, subsample=0.6; total time=   0.3s
# [12:23:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=3, n_estimators=200, subsample=0.6; total time=   0.3s
# [12:23:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.5, max_depth=10, min_child_weight=5, n_estimators=1200, subsample=0.6; total time=   0.7s
# [12:23:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.5, max_depth=10, min_child_weight=5, n_estimators=1200, subsample=0.6; total time=   0.6s
# [12:23:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.5, max_depth=10, min_child_weight=5, n_estimators=1200, subsample=0.6; total time=   0.8s
# [12:23:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.5, max_depth=10, min_child_weight=5, n_estimators=1200, subsample=0.6; total time=   0.6s
# [12:23:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.5, max_depth=10, min_child_weight=5, n_estimators=1200, subsample=0.6; total time=   0.6s
# [12:23:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.6, max_depth=20, min_child_weight=5, n_estimators=900, subsample=0.8; total time=   0.7s
# [12:23:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.6, max_depth=20, min_child_weight=5, n_estimators=900, subsample=0.8; total time=   0.7s
# [12:23:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.6, max_depth=20, min_child_weight=5, n_estimators=900, subsample=0.8; total time=   0.5s
# [12:23:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.6, max_depth=20, min_child_weight=5, n_estimators=900, subsample=0.8; total time=   0.9s
# [12:23:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.6, max_depth=20, min_child_weight=5, n_estimators=900, subsample=0.8; total time=   0.7s
# [12:23:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=6, n_estimators=800, subsample=0.7; total time=   1.4s
# [12:23:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=6, n_estimators=800, subsample=0.7; total time=   1.4s
# [12:23:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=6, n_estimators=800, subsample=0.7; total time=   1.4s
# [12:23:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=6, n_estimators=800, subsample=0.7; total time=   1.4s
# [12:23:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=6, n_estimators=800, subsample=0.7; total time=   1.4s
# [12:23:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.6, max_depth=30, min_child_weight=3, n_estimators=600, subsample=0.7; total time=   0.5s
# [12:23:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.6, max_depth=30, min_child_weight=3, n_estimators=600, subsample=0.7; total time=   0.4s
# [12:23:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.6, max_depth=30, min_child_weight=3, n_estimators=600, subsample=0.7; total time=   0.3s
# [12:23:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.6, max_depth=30, min_child_weight=3, n_estimators=600, subsample=0.7; total time=   0.3s
# [12:23:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.6, max_depth=30, min_child_weight=3, n_estimators=600, subsample=0.7; total time=   0.5s
# [12:23:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=3, n_estimators=300, subsample=0.7; total time=   0.2s
# [12:23:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=3, n_estimators=300, subsample=0.7; total time=   0.2s
# [12:23:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=3, n_estimators=300, subsample=0.7; total time=   0.2s
# [12:23:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=3, n_estimators=300, subsample=0.7; total time=   0.2s
# [12:23:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=3, n_estimators=300, subsample=0.7; total time=   0.2s
# [12:23:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=7, n_estimators=300, subsample=0.7; total time=   0.6s
# [12:23:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=7, n_estimators=300, subsample=0.7; total time=   0.6s
# [12:23:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=7, n_estimators=300, subsample=0.7; total time=   0.6s
# [12:23:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=7, n_estimators=300, subsample=0.7; total time=   0.6s
# [12:23:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=7, n_estimators=300, subsample=0.7; total time=   0.6s
# [12:23:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.3, max_depth=15, min_child_weight=3, n_estimators=1100, subsample=0.8; total time=   0.7s
# [12:23:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.3, max_depth=15, min_child_weight=3, n_estimators=1100, subsample=0.8; total time=   0.6s
# [12:23:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.3, max_depth=15, min_child_weight=3, n_estimators=1100, subsample=0.8; total time=   0.6s
# [12:23:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.3, max_depth=15, min_child_weight=3, n_estimators=1100, subsample=0.8; total time=   0.8s
# [12:23:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.3, max_depth=15, min_child_weight=3, n_estimators=1100, subsample=0.8; total time=   0.6s
# [12:23:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.5, max_depth=10, min_child_weight=4, n_estimators=400, subsample=0.6; total time=   0.5s
# [12:23:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.5, max_depth=10, min_child_weight=4, n_estimators=400, subsample=0.6; total time=   0.4s
# [12:23:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.5, max_depth=10, min_child_weight=4, n_estimators=400, subsample=0.6; total time=   0.3s
# [12:23:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.5, max_depth=10, min_child_weight=4, n_estimators=400, subsample=0.6; total time=   0.5s
# [12:23:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.5, max_depth=10, min_child_weight=4, n_estimators=400, subsample=0.6; total time=   0.4s
# [12:23:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.6, max_depth=15, min_child_weight=6, n_estimators=500, subsample=0.6; total time=   0.8s
# [12:23:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.6, max_depth=15, min_child_weight=6, n_estimators=500, subsample=0.6; total time=   0.6s
# [12:23:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.6, max_depth=15, min_child_weight=6, n_estimators=500, subsample=0.6; total time=   0.7s
# [12:23:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.6, max_depth=15, min_child_weight=6, n_estimators=500, subsample=0.6; total time=   0.6s
# [12:23:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.6, max_depth=15, min_child_weight=6, n_estimators=500, subsample=0.6; total time=   0.7s
# [12:23:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.6, max_depth=10, min_child_weight=4, n_estimators=500, subsample=0.7; total time=   0.3s
# [12:23:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.6, max_depth=10, min_child_weight=4, n_estimators=500, subsample=0.7; total time=   0.3s
# [12:23:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.6, max_depth=10, min_child_weight=4, n_estimators=500, subsample=0.7; total time=   0.3s
# [12:23:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.6, max_depth=10, min_child_weight=4, n_estimators=500, subsample=0.7; total time=   0.3s
# [12:23:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.6, max_depth=10, min_child_weight=4, n_estimators=500, subsample=0.7; total time=   0.3s
# [12:23:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=100, subsample=0.6; total time=   0.1s
# [12:23:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=100, subsample=0.6; total time=   0.1s
# [12:23:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=100, subsample=0.6; total time=   0.1s
# [12:23:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=100, subsample=0.6; total time=   0.1s
# [12:23:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=100, subsample=0.6; total time=   0.1s
# [12:23:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.3, max_depth=15, min_child_weight=4, n_estimators=900, subsample=0.8; total time=   1.0s
# [12:23:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.3, max_depth=15, min_child_weight=4, n_estimators=900, subsample=0.8; total time=   0.6s
# [12:23:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.3, max_depth=15, min_child_weight=4, n_estimators=900, subsample=0.8; total time=   0.6s
# [12:23:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.3, max_depth=15, min_child_weight=4, n_estimators=900, subsample=0.8; total time=   1.2s
# [12:23:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.3, max_depth=15, min_child_weight=4, n_estimators=900, subsample=0.8; total time=   0.6s
# [12:24:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.05, max_depth=20, min_child_weight=5, n_estimators=700, subsample=0.6; total time=   1.3s
# [12:24:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.05, max_depth=20, min_child_weight=5, n_estimators=700, subsample=0.6; total time=   1.3s
# [12:24:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.05, max_depth=20, min_child_weight=5, n_estimators=700, subsample=0.6; total time=   1.3s
# [12:24:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.05, max_depth=20, min_child_weight=5, n_estimators=700, subsample=0.6; total time=   1.3s
# [12:24:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.05, max_depth=20, min_child_weight=5, n_estimators=700, subsample=0.6; total time=   1.3s
# [12:24:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=6, n_estimators=700, subsample=0.6; total time=   0.9s
# [12:24:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=6, n_estimators=700, subsample=0.6; total time=   0.9s
# [12:24:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=6, n_estimators=700, subsample=0.6; total time=   0.9s
# [12:24:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=6, n_estimators=700, subsample=0.6; total time=   0.9s
# [12:24:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=6, n_estimators=700, subsample=0.6; total time=   0.9s
# [12:24:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=800, subsample=0.7; total time=   0.6s
# [12:24:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=800, subsample=0.7; total time=   0.6s
# [12:24:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=800, subsample=0.7; total time=   0.6s
# [12:24:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ...
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=6, n_estimators=800, subsample=0.6; total time=   1.5s
# [12:27:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=6, n_estimators=800, subsample=0.6; total time=   1.3s
# [12:27:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=6, n_estimators=800, subsample=0.6; total time=   1.4s
# [12:27:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.3, max_depth=15, min_child_weight=3, n_estimators=600, subsample=0.7; total time=   0.8s
# [12:27:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.3, max_depth=15, min_child_weight=3, n_estimators=600, subsample=0.7; total time=   0.6s
# [12:27:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.3, max_depth=15, min_child_weight=3, n_estimators=600, subsample=0.7; total time=   0.5s
# [12:27:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.3, max_depth=15, min_child_weight=3, n_estimators=600, subsample=0.7; total time=   0.7s
# [12:27:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.3, max_depth=15, min_child_weight=3, n_estimators=600, subsample=0.7; total time=   0.6s
# [12:27:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=4, n_estimators=300, subsample=0.7; total time=   0.4s
# [12:27:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=4, n_estimators=300, subsample=0.7; total time=   0.4s
# [12:27:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=4, n_estimators=300, subsample=0.7; total time=   0.4s
# [12:27:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=4, n_estimators=300, subsample=0.7; total time=   0.4s
# [12:27:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.1, max_depth=10, min_child_weight=4, n_estimators=300, subsample=0.7; total time=   0.4s
# [12:27:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=7, n_estimators=700, subsample=0.6; total time=   1.1s
# [12:27:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=7, n_estimators=700, subsample=0.6; total time=   1.1s
# [12:27:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=7, n_estimators=700, subsample=0.6; total time=   1.1s
# [12:27:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=7, n_estimators=700, subsample=0.6; total time=   1.1s
# [12:27:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=7, n_estimators=700, subsample=0.6; total time=   1.1s
# [12:27:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=7, n_estimators=300, subsample=0.6; total time=   0.5s
# [12:27:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=7, n_estimators=300, subsample=0.6; total time=   0.5s
# [12:27:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=7, n_estimators=300, subsample=0.6; total time=   0.5s
# [12:27:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=7, n_estimators=300, subsample=0.6; total time=   0.5s
# [12:27:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.3, max_depth=30, min_child_weight=7, n_estimators=300, subsample=0.6; total time=   0.5s
# [12:27:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=4, n_estimators=100, subsample=0.7; total time=   0.2s
# [12:27:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=4, n_estimators=100, subsample=0.7; total time=   0.2s
# [12:27:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=4, n_estimators=100, subsample=0.7; total time=   0.2s
# [12:27:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=4, n_estimators=100, subsample=0.7; total time=   0.2s
# [12:27:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.05, max_depth=30, min_child_weight=4, n_estimators=100, subsample=0.7; total time=   0.2s
# [12:27:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=5, n_estimators=500, subsample=0.6; total time=   0.8s
# [12:27:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=5, n_estimators=500, subsample=0.6; total time=   0.8s
# [12:27:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=5, n_estimators=500, subsample=0.6; total time=   0.9s
# [12:27:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=5, n_estimators=500, subsample=0.6; total time=   0.8s
# [12:27:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.05, max_depth=15, min_child_weight=5, n_estimators=500, subsample=0.6; total time=   0.8s
# [12:27:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.6, max_depth=25, min_child_weight=5, n_estimators=500, subsample=0.6; total time=   0.7s
# [12:27:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.6, max_depth=25, min_child_weight=5, n_estimators=500, subsample=0.6; total time=   0.5s
# [12:27:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.6, max_depth=25, min_child_weight=5, n_estimators=500, subsample=0.6; total time=   0.5s
# [12:27:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.6, max_depth=25, min_child_weight=5, n_estimators=500, subsample=0.6; total time=   0.7s
# [12:27:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.6, max_depth=25, min_child_weight=5, n_estimators=500, subsample=0.6; total time=   0.6s
# [12:27:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=3, n_estimators=1100, subsample=0.8; total time=   0.5s
# [12:27:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=3, n_estimators=1100, subsample=0.8; total time=   0.5s
# [12:27:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=3, n_estimators=1100, subsample=0.8; total time=   0.5s
# [12:27:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=3, n_estimators=1100, subsample=0.8; total time=   0.6s
# [12:27:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.5, max_depth=20, min_child_weight=3, n_estimators=1100, subsample=0.8; total time=   0.5s
# [12:27:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=4, n_estimators=200, subsample=0.6; total time=   0.2s
# [12:27:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=4, n_estimators=200, subsample=0.6; total time=   0.2s
# [12:27:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=4, n_estimators=200, subsample=0.6; total time=   0.1s
# [12:27:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=4, n_estimators=200, subsample=0.6; total time=   0.2s
# [12:27:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.3, max_depth=5, min_child_weight=4, n_estimators=200, subsample=0.6; total time=   0.2s
# [12:27:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=5, n_estimators=300, subsample=0.8; total time=   0.7s
# [12:27:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=5, n_estimators=300, subsample=0.8; total time=   0.7s
# [12:27:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=5, n_estimators=300, subsample=0.8; total time=   0.6s
# [12:27:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=5, n_estimators=300, subsample=0.8; total time=   0.6s
# [12:27:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.3, max_depth=20, min_child_weight=5, n_estimators=300, subsample=0.8; total time=   0.6s
# [12:27:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=7, n_estimators=300, subsample=0.6; total time=   0.5s
# [12:27:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=7, n_estimators=300, subsample=0.6; total time=   0.5s
# [12:27:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=7, n_estimators=300, subsample=0.6; total time=   0.5s
# [12:27:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=7, n_estimators=300, subsample=0.6; total time=   0.5s
# [12:27:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.1, max_depth=30, min_child_weight=7, n_estimators=300, subsample=0.6; total time=   0.5s
# [12:27:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=900, subsample=0.6; total time=   0.7s
# [12:27:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=900, subsample=0.6; total time=   0.7s
# [12:27:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=900, subsample=0.6; total time=   0.7s
# [12:27:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=900, subsample=0.6; total time=   0.7s
# [12:27:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=900, subsample=0.6; total time=   0.7s
# [12:27:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# RandomizedSearchCV(cv=5, estimator=XGBRegressor(), n_iter=100,
#                    param_distributions={'learning_rate': ['0.05', '0.1', '0.2',
#                                                           '0.3', '0.5', '0.6'],
#                                         'max_depth': [5, 10, 15, 20, 25, 30],
#                                         'min_child_weight': [3, 4, 5, 6, 7],
#                                         'n_estimators': [100, 200, 300, 400,
#                                                          500, 600, 700, 800,
#                                                          900, 1000, 1100,
#                                                          1200],
#                                         'subsample': [0.7, 0.6, 0.8]},
#                    scoring='neg_mean_squared_error', verbose=2)

# %%
xg_random.best_params_
# Out:
# {'learning_rate': '0.05',
#  'max_depth': 5,
#  'min_child_weight': 4,
#  'n_estimators': 600,
#  'subsample': 0.8}

# %%
xg_random.best_params_
# Out:
# {'learning_rate': '0.05',
#  'max_depth': 5,
#  'min_child_weight': 4,
#  'n_estimators': 600,
#  'subsample': 0.8}

# %%
xg_random.best_score_
# Out:
# -1394.8868966247

# %%
predictions=xg_random.predict(X_test)

# %%
sns.distplot(y_test-predictions)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.scatter(y_test,predictions)

# %%
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 21.48077070945041
# MSE: 1458.9693379784478
# RMSE: 38.19645713909142

# %%
score.mean()
# Out:
# 0.6582827367763413
